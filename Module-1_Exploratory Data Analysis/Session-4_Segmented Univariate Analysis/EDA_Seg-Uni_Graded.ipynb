# %%
import pandas as pd
df = pd.read_csv('/content/EDA_census.csv')
df = df.dropna(axis=1)
df.describe()
# Out:
#         State_Code  Distt_Code     T_Persons       T_Males     T_Females  \
# count  3132.000000      3132.0  3.132000e+03  3.132000e+03  3.132000e+03
# mean     17.500000         0.0  3.092861e+06  1.592006e+06  1.500855e+06
# std      10.389954         0.0  2.882232e+07  1.483375e+07  1.398926e+07
# min       0.000000         0.0  6.000000e+00  4.000000e+00  2.000000e+00
# 25%       8.750000         0.0  2.141225e+04  1.116850e+04  1.014875e+04
# 50%      17.500000         0.0  2.389940e+05  1.232525e+05  1.166540e+05
# 75%      26.250000         0.0  1.123899e+06  5.782720e+05  5.429365e+05
# max      35.000000         0.0  1.210855e+09  6.232703e+08  5.875847e+08
#
#          IL_Persons      IL_Males    IL_Females     L_Persons       L_Males  \
# count  3.132000e+03  3.132000e+03  3.132000e+03  3.132000e+03  3.132000e+03
# mean   1.142315e+06  4.814984e+05  6.608162e+05  1.950546e+06  1.110507e+06
# std    1.150330e+07  4.966519e+06  6.565306e+06  1.791240e+07  1.023041e+07
# ...

# %%
df.head()
# Out:
#    State_Code  Distt_Code Area_Name  T/R/U   Age_Grp   T_Persons    T_Males  \
# 0           0           0     INDIA  Total  All ages  1210854977  623270258
# 1           0           0     INDIA  Total       0-6   164515253   85752254
# 2           0           0     INDIA  Total         7    24826640   12903364
# 3           0           0     INDIA  Total         8    26968373   14061937
# 4           0           0     INDIA  Total         9    23424638   12214985
#
#    T_Females  IL_Persons   IL_Males  IL_Females  L_Persons    L_Males  \
# 0  587584719   447216165  188506636   258709529  763638812  434763622
# 1   78762999   164515253   85752254    78762999          0          0
# 2   11923276     6748214    3388683     3359531   18078426    9514681
# 3   12906436     4131414    2013742     2117672   22836959   12048195
# 4   11209653     2491904    1198339     1293565   20932734   11016646
#
#    L_Females
# 0  328875190
# 1          0
# 2    8563745
# 3   10788764
# 4    9916088

# %%
IL_Females = df.loc[((df['Age_Grp'] == '20-24') & (df['Area_Name'] == 'INDIA') & (df['T/R/U'] == 'Total')), 'IL_Females']

Total_Females = df.loc[((df['Age_Grp'] == '20-24') & (df['Area_Name'] == 'INDIA') & (df['T/R/U'] == 'Total')), 'T_Females']

print(IL_Females)
print(Total_Females)
# Out:
# 15    12212466
# Name: IL_Females, dtype: int64
# 15    53839529
# Name: T_Females, dtype: int64

# %%
per_IL = IL_Females/Total_Females*100
print(per_IL)
# Out:
# 15    22.683085
# dtype: float64
